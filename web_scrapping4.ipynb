# %%
import requests
from bs4 import BeautifulSoup

# %%
session = requests.session()

# %%
registrationNo = 123
year=1960

# %%
def IMR_home_page():
    
    url_link = "https://www.nmc.org.in/information-desk/indian-medical-register/"
    headers = {
        "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36"
    }
    response = session.get(url_link,headers = headers)
    if response.status_code==200:
        return response
    else:
        return False

# %%
response_from_IMR = IMR_home_page()
print(response_from_IMR)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response_from_IMR.text,'lxml')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="en-US">
# <![endif]--><!--[if IE 8]>
# <html class="ie ie8" lang="en-US">
# <![endif]--><!--[if !(IE 7) & !(IE 8)]><!--><html lang="en-US">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>
# Indian Medical Register | NMC</title>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://www.nmc.org.in/xmlrpc.php" rel="pingback"/>
# <!--[if lt IE 9]>
#         <script src="https://www.nmc.org.in/wp-content/themes/twentyfourteen/js/html5.js"></script>
#         <![endif]-->
# <!-- Added by Simplest Gallery Plugin v. 4.4 BEGIN -->
# <!-- SG default gallery type is: lightbox -->
# <!-- Added by FancyBox without labels BEGIN -->
# <!-- Lighbox module for Simplest Gallery, v. 1.1 -->
# <!-- Added by FancyBox without labels END -->
# ...

# %%
# second fetching the data

# %%
def fetch_data():
    
    url_link = "https://www.nmc.org.in/MCIRest/open/getPaginatedData?service=getPaginatedDoctor&draw=1&columns%5B0%5D%5Bdata%5D=0&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=true&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=1&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=true&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=2&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=3&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=4&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=true&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=5&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=6&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=0&order%5B0%5D%5Bdir%5D=asc&start=0&length=500&search%5Bvalue%5D=&search%5Bregex%5D=false&name=&registrationNo=123&smcId=1&year=1960&_=1679142838480"
    headers = {
        
        "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36",
        "Referer": "https://www.nmc.org.in/information-desk/indian-medical-register/",
        "Host": "www.nmc.org.in",
        "X-Requested-With": "XMLHttpRequest"
    }
    payload = {
        "smcId": "1",
        "registrationNo":registrationNo,
        "year":year,
        "_": "1679142838480",
        "start": "0",
        "length": "500",
        "search[value]":"",
        "search[regex]": "false",
        "name":"",
        "service": "getPaginatedDoctor",
        "draw": "1",
    }
    response = session.get(url_link,headers=headers,data=payload)
    print(response.content)
    return response

# %%
second_response = fetch_data()
# Out:
# b'{"recordsFiltered":12,"data":[[1,1960,"1123","Andhra Pradesh Medical Council","Owk Ankanna","O P Ankanna","<a href=\\"javascript:void(0);\\" onclick=\\"openDoctorDetailsnew(\'563191\', \'1123\')\\">View<\\/a>"],[2,1960,"123","Andhra Pradesh Medical Council","Sripaurapudilly Mallikarjuna Rao","S Venkatarttanam","<a href=\\"javascript:void(0);\\" onclick=\\"openDoctorDetailsnew(\'562560\', \'123\')\\">View<\\/a>"],[3,1960,"1230","Andhra Pradesh Medical Council","Injamuri Ranga Rao","I Hanumaiah","<a href=\\"javascript:void(0);\\" onclick=\\"openDoctorDetailsnew(\'562686\', \'1230\')\\">View<\\/a>"],[4,1960,"1231","Andhra Pradesh Medical Council","Jonnalagadda Mallikarjunaswamy","Dr. J Papayyaraju","<a href=\\"javascript:void(0);\\" onclick=\\"openDoctorDetailsnew(\'562949\', \'1231\')\\">View<\\/a>"],[5,1960,"1232","Andhra Pradesh Medical Council","Pedarala Madhusudhana Rao","P Kotiah","<a href=\\"javascript:void(0);\\" onclick=\\"openDoctorDetailsnew(\'562940\', \'1232\')\\">View<\\
# ...

# %%
soup = BeautifulSoup(second_response.text,'lxml')

# %%
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    {"recordsFiltered":12,"data":[[1,1960,"1123","Andhra Pradesh Medical Council","Owk Ankanna","O P Ankanna","
#    <a href='\"javascript:void(0);\"' onclick="\&quot;openDoctorDetailsnew('563191',">
#     View"],[2,1960,"123","Andhra Pradesh Medical Council","Sripaurapudilly Mallikarjuna Rao","S Venkatarttanam","
#    </a>
#    <a href='\"javascript:void(0);\"' onclick="\&quot;openDoctorDetailsnew('562560',">
#     View"],[3,1960,"1230","Andhra Pradesh Medical Council","Injamuri Ranga Rao","I Hanumaiah","
#    </a>
#    <a href='\"javascript:void(0);\"' onclick="\&quot;openDoctorDetailsnew('562686',">
#     View"],[4,1960,"1231","Andhra Pradesh Medical Council","Jonnalagadda Mallikarjunaswamy","Dr. J Papayyaraju","
#    </a>
#    <a href='\"javascript:void(0);\"' onclick="\&quot;openDoctorDetailsnew('562949',">
#     View"],[5,1960,"1232","Andhra Pradesh Medical Council","Pedarala Madhusudhana Rao","P Kotiah","
#    </a>
# ...

# %%
json_data = soup.p.text.strip()

# %%
import json
data = json.loads(json_data)

# %%
res = []
for item in data['data']:
    rec = {
        'Name':item[4],
        'yearInfo':item[1],
        'StateMedicalCouncil':item[3],
        "FatherName":item[5]
    }
    res.append(rec)

# %%
result = json.dumps(res,indent=4)

# %%
print(result)
# Out:
# [
#     {
#         "Name": "Owk Ankanna",
#         "yearInfo": 1960,
#         "StateMedicalCouncil": "Andhra Pradesh Medical Council",
#         "FatherName": "O P Ankanna"
#     },
#     {
#         "Name": "Sripaurapudilly Mallikarjuna Rao",
#         "yearInfo": 1960,
#         "StateMedicalCouncil": "Andhra Pradesh Medical Council",
#         "FatherName": "S Venkatarttanam"
#     },
#     {
#         "Name": "Injamuri Ranga Rao",
#         "yearInfo": 1960,
#         "StateMedicalCouncil": "Andhra Pradesh Medical Council",
#         "FatherName": "I Hanumaiah"
#     },
#     {
#         "Name": "Jonnalagadda Mallikarjunaswamy",
#         "yearInfo": 1960,
#         "StateMedicalCouncil": "Andhra Pradesh Medical Council",
#         "FatherName": "Dr. J Papayyaraju"
#     },
#     {
#         "Name": "Pedarala Madhusudhana Rao",
#         "yearInfo": 1960,
#         "StateMedicalCouncil": "Andhra Pradesh Medical Council",
#         "FatherName": "P Kotiah"
#     },
#     {
# ...
